# %% [markdown]
# # Question

# %% [markdown]
# Acquire power data from this source for at least 10 days and not more than 40 days. The website limits the window size, so you will need to download multiple files. Load the data into a Jupyter Notebook. Combine the multiple input files to create a single dataframe.
#
# Create two bar graphs of the power consumption per hour.
#
# One bar graph has 24 bars; each bar is the average across all days for that hour
# one bar graph has 24*(number of days) bars. Your choice of average or sum for each hour. Label the y-axis appropriately.

# %% [markdown]
# # Answer:

# %%
import pandas as pd
from datetime import datetime

# %% [markdown]
# Loading the CSV1 into a dataframe into df1

# %%
df1 = pd.read_csv("RollingSystemDemand_20191012_1934.csv",index_col=False,
                         skiprows=1,
                         skipfooter=1, engine='python',
                         header=None)
df1.tail()
# Out:
#        0               1      2
# 1723  VD  20191006233500  22309
# 1724  VD  20191006234000  22193
# 1725  VD  20191006234500  22081
# 1726  VD  20191006235000  22045
# 1727  VD  20191006235500  21942

# %% [markdown]
# Loading the CSV2 into a dataframe df2

# %%
df2 = pd.read_csv("RollingSystemDemand_20191012_1935.csv",index_col=False,
                         skiprows=1,
                         skipfooter=1, engine='python',
                         header=None)
df2.tail()
# Out:
#        0               1      2
# 1670  VD  20191012191000  34460
# 1671  VD  20191012191500  34120
# 1672  VD  20191012192000  33962
# 1673  VD  20191012192500  33833
# 1674  VD  20191012193000  33577

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
# This link has the code to merge 2 dataframes

# %%
df1 = pd.concat([df1,df2])
df1.index=range(len(df1))
df1.tail()
# Out:
#        0               1      2
# 3398  VD  20191012191000  34460
# 3399  VD  20191012191500  34120
# 3400  VD  20191012192000  33962
# 3401  VD  20191012192500  33833
# 3402  VD  20191012193000  33577

# %% [markdown]
# Renaming the columns

# %%
df1.columns=['VD','time of measurement','demand level']

# %%
df1.tail()
# Out:
#       VD  time of measurement  demand level
# 3398  VD       20191012191000         34460
# 3399  VD       20191012191500         34120
# 3400  VD       20191012192000         33962
# 3401  VD       20191012192500         33833
# 3402  VD       20191012193000         33577

# %% [markdown]
# Changing the format of time

# %%
df1['time of measurement']=pd.to_datetime(df1['time of measurement'].astype(str),format='%Y%m%d%H%M%S')
df1
# Out:
#       VD time of measurement  demand level
# 0     VD 2019-10-01 00:00:00         22008
# 1     VD 2019-10-01 00:05:00         22379
# 2     VD 2019-10-01 00:10:00         22361
# 3     VD 2019-10-01 00:15:00         22445
# 4     VD 2019-10-01 00:20:00         22377
# 5     VD 2019-10-01 00:25:00         22461
# 6     VD 2019-10-01 00:30:00         22515
# 7     VD 2019-10-01 00:35:00         22629
# 8     VD 2019-10-01 00:40:00         22702
# 9     VD 2019-10-01 00:45:00         22706
# 10    VD 2019-10-01 00:50:00         22814
# 11    VD 2019-10-01 00:55:00         22818
# 12    VD 2019-10-01 01:00:00         22656
# 13    VD 2019-10-01 01:05:00         22514
# 14    VD 2019-10-01 01:10:00         22492
# 15    VD 2019-10-01 01:15:00         22450
# 16    VD 2019-10-01 01:20:00         22475
# 17    VD 2019-10-01 01:25:00         22382
# 18    VD 2019-10-01 01:30:00         22275
# 19    VD 2019-10-01 01:35:00         22253
# 20    VD 2019-10-01 01:40:00         22167
# 21    VD 2019-10-01 01:45:00         22148
# 22    VD 2019-10-01 01:50:00         22149
# 23    VD 2019-10-01 01:55:00         22115
# 24    VD 2019-10-01 02:00:00         22053
# 25    VD 2019-10-01 02:05:00         21730
# 26    VD 2019-10-01 02:10:00         21637
# 27    VD 2019-10-01 02:15:00         21639
# 28    VD 2019-10-01 02:20:00         21570
# 29    VD 2019-10-01 02:25:00         21492
# ...   ..                 ...           ...
# 3373  VD 2019-10-12 17:05:00         35665
# 3374  VD 2019-10-12 17:10:00         35767
# 3375  VD 2019-10-12 17:15:00         35835
# 3376  VD 2019-10-12 17:20:00         35917
# 3377  VD 2019-10-12 17:25:00         35999
# 3378  VD 2019-10-12 17:30:00         36135
# 3379  VD 2019-10-12 17:35:00         36227
# 3380  VD 2019-10-12 17:40:00         36243
# 3381  VD 2019-10-12 17:45:00         36268
# 3382  VD 2019-10-12 17:50:00         36223
# 3383  VD 2019-10-12 17:55:00         36215
# 3384  VD 2019-10-12 18:00:00         36125
# 3385  VD 2019-10-12 18:05:00         35976
# 3386  VD 2019-10-12 18:10:00         35961
# 3387  VD 2019-10-12 18:15:00         35802
# 3388  VD 2019-10-12 18:20:00         35629
# 3389  VD 2019-10-12 18:25:00         35475
# 3390  VD 2019-10-12 18:30:00         35318
# 3391  VD 2019-10-12 18:35:00         35341
# 3392  VD 2019-10-12 18:40:00         35264
# 3393  VD 2019-10-12 18:45:00         35142
# 3394  VD 2019-10-12 18:50:00         35193
# 3395  VD 2019-10-12 18:55:00         35044
# 3396  VD 2019-10-12 19:00:00         34769
# 3397  VD 2019-10-12 19:05:00         34640
# 3398  VD 2019-10-12 19:10:00         34460
# 3399  VD 2019-10-12 19:15:00         34120
# 3400  VD 2019-10-12 19:20:00         33962
# 3401  VD 2019-10-12 19:25:00         33833
# 3402  VD 2019-10-12 19:30:00         33577
#
# [3403 rows x 3 columns]

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.__version__
# Out:
# '3.1.0'

# %% [markdown]
# Extracting the hour from the "time of measurement" field and storing it as a column in the dataframe df1

# %%
hour=[]
for i in range(len(df1)):
    hour.append(df1["time of measurement"][i].hour)

# %%
df1['hour']=hour
#df1['hour']=df1['hour'].astype('int64')

# %%
df1
# Out:
#       VD time of measurement  demand level  hour
# 0     VD 2019-10-01 00:00:00         22008     0
# 1     VD 2019-10-01 00:05:00         22379     0
# 2     VD 2019-10-01 00:10:00         22361     0
# 3     VD 2019-10-01 00:15:00         22445     0
# 4     VD 2019-10-01 00:20:00         22377     0
# 5     VD 2019-10-01 00:25:00         22461     0
# 6     VD 2019-10-01 00:30:00         22515     0
# 7     VD 2019-10-01 00:35:00         22629     0
# 8     VD 2019-10-01 00:40:00         22702     0
# 9     VD 2019-10-01 00:45:00         22706     0
# 10    VD 2019-10-01 00:50:00         22814     0
# 11    VD 2019-10-01 00:55:00         22818     0
# 12    VD 2019-10-01 01:00:00         22656     1
# 13    VD 2019-10-01 01:05:00         22514     1
# 14    VD 2019-10-01 01:10:00         22492     1
# 15    VD 2019-10-01 01:15:00         22450     1
# 16    VD 2019-10-01 01:20:00         22475     1
# 17    VD 2019-10-01 01:25:00         22382     1
# 18    VD 2019-10-01 01:30:00         22275     1
# 19    VD 2019-10-01 01:35:00         22253     1
# 20    VD 2019-10-01 01:40:00         22167     1
# 21    VD 2019-10-01 01:45:00         22148     1
# 22    VD 2019-10-01 01:50:00         22149     1
# 23    VD 2019-10-01 01:55:00         22115     1
# 24    VD 2019-10-01 02:00:00         22053     2
# 25    VD 2019-10-01 02:05:00         21730     2
# 26    VD 2019-10-01 02:10:00         21637     2
# 27    VD 2019-10-01 02:15:00         21639     2
# 28    VD 2019-10-01 02:20:00         21570     2
# 29    VD 2019-10-01 02:25:00         21492     2
# ...   ..                 ...           ...   ...
# 3373  VD 2019-10-12 17:05:00         35665    17
# 3374  VD 2019-10-12 17:10:00         35767    17
# 3375  VD 2019-10-12 17:15:00         35835    17
# 3376  VD 2019-10-12 17:20:00         35917    17
# 3377  VD 2019-10-12 17:25:00         35999    17
# 3378  VD 2019-10-12 17:30:00         36135    17
# 3379  VD 2019-10-12 17:35:00         36227    17
# 3380  VD 2019-10-12 17:40:00         36243    17
# 3381  VD 2019-10-12 17:45:00         36268    17
# 3382  VD 2019-10-12 17:50:00         36223    17
# 3383  VD 2019-10-12 17:55:00         36215    17
# 3384  VD 2019-10-12 18:00:00         36125    18
# 3385  VD 2019-10-12 18:05:00         35976    18
# 3386  VD 2019-10-12 18:10:00         35961    18
# 3387  VD 2019-10-12 18:15:00         35802    18
# 3388  VD 2019-10-12 18:20:00         35629    18
# 3389  VD 2019-10-12 18:25:00         35475    18
# 3390  VD 2019-10-12 18:30:00         35318    18
# 3391  VD 2019-10-12 18:35:00         35341    18
# 3392  VD 2019-10-12 18:40:00         35264    18
# 3393  VD 2019-10-12 18:45:00         35142    18
# 3394  VD 2019-10-12 18:50:00         35193    18
# 3395  VD 2019-10-12 18:55:00         35044    18
# 3396  VD 2019-10-12 19:00:00         34769    19
# 3397  VD 2019-10-12 19:05:00         34640    19
# 3398  VD 2019-10-12 19:10:00         34460    19
# 3399  VD 2019-10-12 19:15:00         34120    19
# 3400  VD 2019-10-12 19:20:00         33962    19
# 3401  VD 2019-10-12 19:25:00         33833    19
# 3402  VD 2019-10-12 19:30:00         33577    19
#
# [3403 rows x 4 columns]

# %% [markdown]
# # Graph displaying the Average Power Consumed in a hour for all days

# %%
x=df1.groupby('hour')
y=x['demand level'].mean()

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 15
fig_size[1] = 5
plt.rcParams["figure.figsize"] = fig_size

# %%
_=y.plot(x="hour", y="demand level",kind="bar")
_=plt.ylabel('Avg Power',fontsize=12)
_=plt.xlabel('Time in Hour',fontsize=12)
_=plt.title('average across all days for that hour')

# %% [markdown]
# https://www.programiz.com/python-programming/datetime/current-datetime
# Above link contain the code to get only date from "time of measurement" field

# %%
date=[]
for i in range(len(df1)):
    date.append(df1["time of measurement"][i].strftime("%d/%m/%Y"))

# %% [markdown]
# Storing that date as a Column in "df1" Dataframe

# %%
df1['date']=date

# %% [markdown]
# # generating a graph for the avg power consumtion for each day at a particular hour

# %% [markdown]
# Calulating the mean for the power consumption in a day at particular hour

# %%
a=df1.groupby(['date','hour'])
b=a['demand level'].mean()

# %% [markdown]
# Adjusting the size of the graph

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 60
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size

# %% [markdown]
# Generating the graph (Double click the graph to zoom in)

# %%
from itertools import cycle, islice
my_colors = list(islice(cycle(['b','b','b','b','b','b','b','b','b','b','b','b','b','b','b','b','b','b','b','b','b','b','b','b','r','r','r','r','r','r','r','r','r','r','r','r','r','r','r','r','r','r','r','r','r','r','r','r']), None, len(b)))
_=b.plot(x=["date","hour"], y="demand level",kind="bar",color=my_colors)
_=plt.ylabel('Avg Power',fontsize=12)
_=plt.xlabel('Time in date and Hour',fontsize=12)
_=plt.title('average power for each day for that hour')
